# %% [markdown]
# # Example usage

# %%
from autoEDA import autoEDA

# %% [markdown]
# ## I - Data loading
# ### Select the file path and specify its format ("csv", "exel" or "sql")

# %%
EDA = autoEDA()

EDA.load_data("./Salaries.csv", format="csv")
# Out:
# data loaded successfully
#                 Year          Month     usg_apt_id        usg_wac  \
# count  930808.000000  930808.000000  930808.000000  930808.000000
# mean     2006.021361       6.414783   12809.473781      42.511740
# std         8.558831       3.471070    2716.223845      27.571338
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1999.000000       3.000000   11618.000000      22.000000
# 50%      2007.000000       6.000000   12892.000000      33.000000
# 75%      2014.000000       9.000000   13487.000000      72.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  930808.000000  930808.000000  930808.000000  930808.000000
# mean    13484.676238     466.910479   20057.217505       0.599361
# std      1932.601107     288.005971     479.071456       0.490028
# min     10119.000000     106.000000   19386.000000       0.000000
# ...

# %%
EDA.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930808 entries, 0 to 930807
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_dte      930808 non-null  object
#  1   Year          930808 non-null  int64
#  2   Month         930808 non-null  int64
#  3   usg_apt_id    930808 non-null  int64
#  4   usg_apt       930808 non-null  object
#  5   usg_wac       930808 non-null  int64
#  6   fg_apt_id     930808 non-null  int64
#  7   fg_apt        930808 non-null  object
#  8   fg_wac        930808 non-null  int64
#  9   airlineid     930808 non-null  int64
#  10  carrier       927753 non-null  object
#  11  carriergroup  930808 non-null  int64
#  12  type          930808 non-null  object
#  13  Scheduled     930808 non-null  int64
#  14  Charter       930808 non-null  int64
#  15  Total         930808 non-null  int64
# dtypes: int64(11), object(5)
# memory usage: 113.6+ MB

# %% [markdown]
# ## II - Data preprocessing
# ### Perform basic preprocessing steps such as handling missing values and scaling numerical features

# %%
EDA.preprocess()
# Out:
#           data_dte      Year     Month  usg_apt_id usg_apt   usg_wac  \
# 0       05/01/2006  0.533333  0.363636    0.022292     GUM  0.043478
# 1       05/01/2003  0.433333  0.363636    0.003212     ANC  0.000000
# 2       03/01/2007  0.566667  0.181818    0.007901     BOS  0.130435
# 3       12/01/2004  0.466667  1.000000    0.013879     DAL  0.793478
# 4       05/01/2009  0.633333  0.363636    0.036593     MIA  0.347826
# ...            ...       ...       ...         ...     ...       ...
# 930803  07/01/2000  0.333333  0.545455    0.036593     MIA  0.347826
# 930804  04/01/2019  0.966667  0.272727    0.036593     MIA  0.347826
# 930805  08/01/2000  0.333333  0.636364    0.036593     MIA  0.347826
# 930806  09/01/2004  0.466667  0.727273    0.025070     IAH  0.793478
# 930807  05/01/1996  0.200000  0.363636    0.027426     JFK  0.228261
#
#         fg_apt_id fg_apt    fg_wac  airlineid carrier  carriergroup  \
# 0        0.450015    MAJ  0.849252   0.295039     PFQ           1.0
# ...

# %% [markdown]
# ## III -  Features selection
# ### This function drops columns whose variances fall below a specified threshold, while keeping the target column for the next step. You can adjust this threshold based on your data.

# %%
EDA.select_features(threshold=0.01, target_column='Total')
# Out:
# usg_apt_id
# Scheduled
# Charter
#           data_dte      Year     Month usg_apt   usg_wac  fg_apt_id fg_apt  \
# 0       05/01/2006  0.533333  0.363636     GUM  0.043478   0.450015    MAJ
# 1       05/01/2003  0.433333  0.363636     ANC  0.000000   0.552647    OKO
# 2       03/01/2007  0.566667  0.181818     BOS  0.130435   0.374445    KEF
# 3       12/01/2004  0.466667  1.000000     DAL  0.793478   0.909790    YYZ
# 4       05/01/2009  0.633333  0.363636     MIA  0.347826   0.141378    CMW
# ...            ...       ...       ...     ...       ...        ...    ...
# 930803  07/01/2000  0.333333  0.545455     MIA  0.347826   0.515528    NAS
# 930804  04/01/2019  0.966667  0.272727     MIA  0.347826   0.616238    PTY
# 930805  08/01/2000  0.333333  0.636364     MIA  0.347826   0.515528    NAS
# 930806  09/01/2004  0.466667  0.727273     IAH  0.793478   0.815291    VSA
# 930807  05/01/1996  0.200000  0.363636     JFK  0.228261   0.604999    POS
#
# ...

# %%
EDA.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930808 entries, 0 to 930807
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_dte      930808 non-null  object
#  1   Year          930808 non-null  float64
#  2   Month         930808 non-null  float64
#  3   usg_apt       930808 non-null  object
#  4   usg_wac       930808 non-null  float64
#  5   fg_apt_id     930808 non-null  float64
#  6   fg_apt        930808 non-null  object
#  7   fg_wac        930808 non-null  float64
#  8   airlineid     930808 non-null  float64
#  9   carrier       930808 non-null  object
#  10  carriergroup  930808 non-null  float64
#  11  type          930808 non-null  object
#  12  Total         930808 non-null  float64
# dtypes: float64(8), object(5)
# memory usage: 92.3+ MB

# %% [markdown]
# ## VI -  Visualization dashboard
# ### Specify the target column to generate comprehensive visualization dashboards for different column types.

# %%
EDA.generate_dashboard("Total")
